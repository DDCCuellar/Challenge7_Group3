# %% [markdown]
# # Part C - Domain Adaptation
#
# Use domain_adaptation.py to compare no adaptation, fine-tuning and style augmentation.

# %%
from domain_adaptation import build_resnet50_classifier, train_target_finetuning, train_style_augmentation
from challenge7_config import SOURCE_DATA_DIR, TARGET_DATA_DIR
