# %% [markdown]
# # Part B - Neural Style Transfer
#
# Use style_transfer.py to generate synthetic target-domain images.

# %%
from style_transfer import load_image, run_style_transfer, save_output
from challenge7_config import TARGET_DATA_DIR, SYNTHETIC_TARGET_DIR
