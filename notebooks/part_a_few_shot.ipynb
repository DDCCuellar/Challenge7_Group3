# %% [markdown]
# # Part A - Few-Shot Classification
#
# Use classifier.py to train the source-domain model with the Group 3 setup.

# %%
from classifier import build_resnet50_classifier, get_few_shot_loaders
from challenge7_config import SOURCE_DATA_DIR
